# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Importing the dataset
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
abalone = fetch_ucirepo(id=1) 
  
# data (as pandas dataframes) 
X = abalone.data.features 
y = abalone.data.targets 
  
# metadata 
print(abalone.metadata) 
  
# variable information 
print(abalone.variables)
# Out:
# {'uci_id': 1, 'name': 'Abalone', 'repository_url': 'https://archive.ics.uci.edu/dataset/1/abalone', 'data_url': 'https://archive.ics.uci.edu/static/public/1/data.csv', 'abstract': 'Predict the age of abalone from physical measurements', 'area': 'Biology', 'tasks': ['Classification', 'Regression'], 'characteristics': ['Tabular'], 'num_instances': 4177, 'num_features': 8, 'feature_types': ['Categorical', 'Integer', 'Real'], 'demographics': [], 'target_col': ['Rings'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1994, 'last_updated': 'Mon Aug 28 2023', 'dataset_doi': '10.24432/C55C7W', 'creators': ['Warwick Nash', 'Tracy Sellers', 'Simon Talbot', 'Andrew Cawthorn', 'Wes Ford'], 'intro_paper': None, 'additional_info': {'summary': 'Predicting the age of abalone from physical measurements.  The age of abalone is determined by cutting the shell through the cone, staining it, and counting the number of rings through a microscope -
# ...

# %% [markdown]
# Target variable is the Rings(Age) of Abalone - gastropod

# %%
X.describe()
# Out:
#             Length     Diameter       Height  Whole_weight  Shucked_weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera_weight  Shell_weight
# count     4177.000000   4177.000000
# mean         0.180594      0.238831
# std          0.109614      0.139203
# min          0.000500      0.001500
# 25%          0.093500      0.130000
# 50%          0.171000      0.234000
# ...

# %%
X.shape
# Out:
# (4177, 8)

# %%
y.hist()
# Out:
# array([[<Axes: title={'center': 'Rings'}>]], dtype=object)

# %%
ablone_dict = {
    "bin":[],
    "cat" : ['Sex'], 
    "cont":['Length', 'Diameter', 'Height', 'Whole_weight', 'Shucked_weight','Viscera_weight', 'Shell_weight'],
    "ord": [],
    "target":'Rings'
    
}

# %%
abalone_data = pd.concat([X, y], axis=1)
abalone_data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
corr = abalone_data[abalone_data.columns[1:]].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_62384_row0_col0, #T_62384_row1_col1, #T_62384_row2_col2, #T_62384_row3_col3, #T_62384_row4_col4, #T_62384_row5_col5, #T_62384_row6_col6, #T_62384_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_62384_row0_col1, #T_62384_row1_col0 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_62384_row0_col2, #T_62384_row2_col0, #T_62384_row2_col4 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_62384_row0_col3, #T_62384_row1_col3 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_62384_row0_col4 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_62384_row0_col5 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_62384_row0_col6 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_62384_row0_col7, #T_62384_row2_col7 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_62384_row1_col2 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# ...

# %%
abalone_data.to_csv('../data_processed/abalone.csv', index=False)

import pickle
with open('../data_processed/abalone_dict.pkl', 'wb') as f:
    pickle.dump(ablone_dict, f)

f.close()

# %% [markdown]
# Plots:

# %%
abalone_df = pd.concat([X, y], axis=1)
attributes = ablone_dict['cont'] + [ablone_dict['target']]
for feature in attributes:
    plt.figure(figsize=(8, 6))
    sns.histplot(data=abalone_df, x=feature, kde=True, color='blue', bins=30)
    plt.title(f'Distribution of {feature}', fontsize=16)
    plt.xlabel(feature, fontsize=14)
    plt.ylabel('Frequency', fontsize=14)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# %%
numeric_df = abalone_df.select_dtypes(include=['float64', 'int64'])

corr_matrix = numeric_df.corr()

plt.figure(figsize=(12, 8))

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
sns.pairplot(abalone_df, vars=ablone_dict['cont'] + [ablone_dict['target']], diag_kind='kde', corner=True)
plt.suptitle('Pairplot of Continuous Variables and Target', y=1.02, fontsize=16)
plt.tight_layout()
plt.show()
