# %% [markdown]
# ## Preparing algorithm setup

# %%
import random

import networkx as nx
import pandas as pd
from Annealer import Annealer
import pickle
from sklearn.svm import SVC

PATH = "../data_processed/breast-cancer-diagnostic.shuf.lrn.csv"
feature_structure_file =  open('../data_processed/breast-cancer_column_types.pkl', 'rb')
feature_structure = pickle.load(feature_structure_file)

data = pd.read_csv(PATH)

s = SVC()

param_grid1 = {'coef0': [0.0, 0.5, 1.0],
               'degree': [2, 3, 4],
               'gamma': ['scale', 'auto'],
               'kernel':['linear', 'poly', 'rbf', 'sigmoid'],
               'C': [0.1, 1, 10, 100]}

# %%
Annealer.required_keys.issubset(feature_structure.keys())
# Out:
# True

# %%
Annealer_SVC = Annealer(method= SVC(),
                        feature_structure=feature_structure,
                        search_space=param_grid1,
                        data=data)
Annealer_SVC.check_param_space()
# Out:
# True

# %%
Annealer_SVC.preprocessor_step
# Out:
# ColumnTransformer(transformers=[('categorical',
#                                  Pipeline(steps=[('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  []),
#                                 ('numerical',
#                                  Pipeline(steps=[('imputation_mean',
#                                                   SimpleImputer()),
#                                                  ('scaler', RobustScaler())]),
#                                  ['radiusMean', ' textureMean',
#                                   ' perimeterMean', ' areaMean',
#                                   ' smoothnessMean', ' compactnessMean',
#                                   ' concavityMean', ' concavePointsMean',
#                                   ' symmetryMea...
#                                   ' smoothnessStdErr', ' compactnessStdErr',
#                                   ' concavityStdErr', ' concavePointsStdErr',
#                                   ' symmetryStdErr', ' fractalDimensionStdErr',
#                                   ' radiusWorst', ' textureWorst',
#                                   ' perimeterWorst', ' areaWorst',
#                                   ' smoothnessWorst', ' compactnessWorst',
#                                   ' concavityWorst', ' concavePointsWorst',
#                                   ' symmetryWorst', ' fractalDimensionWorst']),
#                                 ('ordinal',
#                                  Pipeline(steps=[('ordinal',
#                                                   OrdinalEncoder())]),
#                                  [])])

# %%
Annealer_SVC.build_graph_search_space()

# %%
Annealer_SVC.hill_climbing()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\TUWien\2024WS\MachineLearning\MachineLearingn2024SS\venv\Lib\site-packages\networkx\classes\graph.py:1372, in Graph.neighbors(self, n)
#    1371 try:
# -> 1372     return iter(self._adj[n])
#    1373 except KeyError as err:
#
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Annealer_SVC.hill_climbing()
#
# File ~\Documents\TUWien\2024WS\MachineLearning\MachineLearingn2024SS\ass3\Annealer.py:123, in Annealer.hill_climbing(self, first_node, max_iter)
#     121 i = 0
#     122 while i<=max_iter and len(candidates) > 0:
# --> 123     neighbors = list(G.neighbors(curr_node))
#     125     if len(neighbors) == 0:
#     126         l_nodes = list( set(G.nodes) - {curr_node})
#
# File ~\Documents\TUWien\2024WS\MachineLearning\MachineLearingn2024SS\venv\Lib\site-packages\networkx\classes\graph.py:1374, in Graph.neighbors(self, n)
#    1372     return iter(self._adj[n])
#    1373 except KeyError as err:
# -> 1374     raise NetworkXError(f"The node {n} is not in the graph.") from err
#
# NetworkXError: The node None is not in the graph.
