# %% [markdown]
# ## Preparing algorithm setup

# %%
import pandas as pd
from Annealer import Annealer
import pickle
from sklearn.svm import SVC

PATH = "../data_processed/breast-cancer-diagnostic.shuf.lrn.csv"
feature_structure_file =  open('../data_processed/breast-cancer_column_types.pkl', 'rb')
feature_structure = pickle.load(feature_structure_file)

data = pd.read_csv(PATH)

s = SVC()

param_grid1 = {'coef0': [0.0, 0.5, 1.0, 2.0, 2.5, 3.0],
               'degree': [2, 3, 4, 5,6],
               'gamma': ['scale', 'auto'],
               'kernel':['linear', 'poly', 'rbf', 'sigmoid'],
               'C': [0.1, 1, 10, 100, 200]}
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from Annealer import Annealer
#       3 import pickle
#       4 from sklearn.svm import SVC
#
# File c:\Users\Anwender\Documents\Private\Uni\ML\ass3\Annealer.py:4
#       2 import numpy as np
#       3 import math
# ----> 4 import networkx as nx
#       5 from sklearn.base import BaseEstimator
#       6 from sklearn.model_selection import cross_val_score
#
# ModuleNotFoundError: No module named 'networkx'

# %%
Annealer_SVC = Annealer(method= SVC(),
                        feature_structure=feature_structure,
                        search_space=param_grid1,
                        max_iter=100,
                        data=data)

# %%
Annealer_SVC.get_full_grid()
# Out:
# [(2.5, 4, 'scale', 'linear', 200),
#  (2.0, 5, 'scale', 'linear', 200),
#  (1.0, 5, 'scale', 'rbf', 10),
#  (1.0, 2, 'scale', 'poly', 200),
#  (2.0, 5, 'scale', 'sigmoid', 200),
#  (2.0, 5, 'scale', 'poly', 10),
#  (0.0, 5, 'auto', 'linear', 0.1),
#  (3.0, 2, 'scale', 'linear', 0.1),
#  (2.5, 3, 'auto', 'sigmoid', 200),
#  (2.5, 5, 'scale', 'linear', 100),
#  (1.0, 5, 'auto', 'sigmoid', 0.1),
#  (0.5, 4, 'scale', 'poly', 1),
#  (0.5, 5, 'auto', 'poly', 1),
#  (0.5, 5, 'auto', 'rbf', 10),
#  (0.5, 4, 'auto', 'sigmoid', 200),
#  (0.0, 5, 'scale', 'sigmoid', 200),
#  (3.0, 5, 'scale', 'linear', 10),
#  (0.0, 4, 'auto', 'poly', 10),
#  (0.0, 3, 'auto', 'rbf', 10),
#  (1.0, 2, 'auto', 'sigmoid', 1),
#  (2.0, 6, 'auto', 'poly', 10),
#  (1.0, 2, 'auto', 'rbf', 10),
#  (2.5, 3, 'auto', 'sigmoid', 1),
#  (0.0, 2, 'auto', 'rbf', 1),
#  (2.0, 3, 'scale', 'linear', 1),
#  (2.0, 6, 'scale', 'linear', 200),
#  (2.0, 2, 'auto', 'linear', 100),
#  (1.0, 4, 'scale', 'poly', 200),
# ...

# %%
Annealer_SVC.grid_search()
# Out:
# Iteration score 1: 0.9298245614035088 with params: {'coef0': 1.0, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly', 'C': 200.0}
# Iteration score 2: 0.9052631578947368 with params: {'coef0': 0.0, 'degree': 2, 'gamma': 'auto', 'kernel': 'sigmoid', 'C': 10.0}
# Iteration score 3: 0.9333333333333333 with params: {'coef0': 1.0, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly', 'C': 10.0}
# Iteration score 4: 0.9368421052631579 with params: {'coef0': 2.5, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear', 'C': 200.0}
# Iteration score 5: 0.9578947368421051 with params: {'coef0': 1.0, 'degree': 6, 'gamma': 'auto', 'kernel': 'sigmoid', 'C': 0.1}
# Iteration score 6: 0.9298245614035088 with params: {'coef0': 2.5, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly', 'C': 10.0}
# Iteration score 7: 0.887719298245614 with params: {'coef0': 2.0, 'degree': 5, 'gamma': 'scale', 'kernel': 'sigmoid', 'C': 100.0}
# ...

# %%
Annealer_SVC.hill_climbing()
# Out:
# Iteration 1: New maximum 0.9824561403508772 with params: {'coef0': 2.5, 'degree': 6, 'gamma': 'scale', 'kernel': 'linear', 'C': 0.1}
# Iteration 21: New maximum 0.9894736842105264 with params: {'coef0': 3.0, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly', 'C': 1}
# ({'coef0': 3.0, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly', 'C': 1},
#  np.float64(0.9894736842105264),
#  58.0103075504303)

# %%
Annealer_SVC.build_search_space2()
len(Annealer_SVC.GX.edges())
# Out:
# 5320

# %%
Annealer_SVC.build_graph_search_space()
len(Annealer_SVC.G.edges())
# Out:
# 10200

# %%
import itertools

search_space1 = pd.DataFrame( Annealer_SVC.get_full_grid())
search_space1.head()
# Out:
#      0  1      2       3      4
# 0  0.0  2  scale  linear    0.1
# 1  0.0  2  scale  linear    1.0
# 2  0.0  2  scale  linear   10.0
# 3  0.0  2  scale  linear  100.0
# 4  0.0  2  scale  linear  200.0

# %%
Annealer_SVC.build_search_space2()

# %%
len(Annealer_SVC.GX.edges())
# Out:
# 160072

# %%
len(Annealer_SVC.G.edges())
# Out:
# 10200

# %%
Annealer_SVC.simulation_annealing()
# Out:
# ({'coef0': 1.0, 'degree': 5, 'gamma': 'auto', 'kernel': 'linear', 'C': 0.1},
#  np.float64(0.9824561403508772),
#  7.671523094177246)

# %%
import pandas as pd
import pickle

from BigDaddyWrapper import BigDaddyWrapper
from Annealer import Annealer
from sklearn.svm import SVC

PATH = "../data_processed/breast-cancer-diagnostic.shuf.lrn.csv"
feature_structure_file =  open('../data_processed/breast-cancer_column_types.pkl', 'rb')
feature_structure = pickle.load(feature_structure_file)

data = pd.read_csv(PATH)


wrapper = BigDaddyWrapper(data, feature_structure, 10)
wrapper.train_model()
X = data.drop(columns=feature_structure['target']).reset_index(drop=True)
wrapper.predict(X)
# Out:
# Start with classifier MLPClassifier()
# Grid len: 5443200
# Iterations: 170.63580424200438
# Start SA with 170.63580424200438 iterations
